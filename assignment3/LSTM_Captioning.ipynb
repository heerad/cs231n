# %% [markdown]
# # Image Captioning with LSTMs
# In the previous exercise you implemented a vanilla RNN and applied it to image captioning. In this notebook you will implement the LSTM update rule and use it for image captioning.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time, os, json
import numpy as np
import matplotlib.pyplot as plt

from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.rnn_layers import *
from cs231n.captioning_solver import CaptioningSolver
from cs231n.classifiers.rnn import CaptioningRNN
from cs231n.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from cs231n.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# # Load MS-COCO data
# As in the previous notebook, we will use the Microsoft COCO dataset for captioning.

# %%
# Load COCO data from disk; this returns a dictionary
# We'll work with dimensionality-reduced features for this notebook, but feel
# free to experiment with the original features by changing the flag below.
data = load_coco_data(pca_features=True)

# Print out all the keys and values from the data dictionary
for k, v in data.items():
    if type(v) == np.ndarray:
        print(k, type(v), v.shape, v.dtype)
    else:
        print(k, type(v), len(v))
# Out:
# train_image_idxs <class 'numpy.ndarray'> (400135,) int32
# val_urls <class 'numpy.ndarray'> (40504,) <U63
# val_image_idxs <class 'numpy.ndarray'> (195954,) int32
# train_captions <class 'numpy.ndarray'> (400135, 17) int32
# val_captions <class 'numpy.ndarray'> (195954, 17) int32
# train_features <class 'numpy.ndarray'> (82783, 512) float32
# val_features <class 'numpy.ndarray'> (40504, 512) float32
# word_to_idx <class 'dict'> 1004
# train_urls <class 'numpy.ndarray'> (82783,) <U63
# idx_to_word <class 'list'> 1004

# %% [markdown]
# # LSTM
# If you read recent papers, you'll see that many people use a variant on the vanialla RNN called Long-Short Term Memory (LSTM) RNNs. Vanilla RNNs can be tough to train on long sequences due to vanishing and exploding gradiants caused by repeated matrix multiplication. LSTMs solve this problem by replacing the simple update rule of the vanilla RNN with a gating mechanism as follows.
#
# Similar to the vanilla RNN, at each timestep we receive an input $x_t\in\mathbb{R}^D$ and the previous hidden state $h_{t-1}\in\mathbb{R}^H$; the LSTM also maintains an $H$-dimensional *cell state*, so we also receive the previous cell state $c_{t-1}\in\mathbb{R}^H$. The learnable parameters of the LSTM are an *input-to-hidden* matrix $W_x\in\mathbb{R}^{4H\times D}$, a *hidden-to-hidden* matrix $W_h\in\mathbb{R}^{4H\times H}$ and a *bias vector* $b\in\mathbb{R}^{4H}$.
#
# At each timestep we first compute an *activation vector* $a\in\mathbb{R}^{4H}$ as $a=W_xx_t + W_hh_{t-1}+b$. We then divide this into four vectors $a_i,a_f,a_o,a_g\in\mathbb{R}^H$ where $a_i$ consists of the first $H$ elements of $a$, $a_f$ is the next $H$ elements of $a$, etc. We then compute the *input gate* $g\in\mathbb{R}^H$, *forget gate* $f\in\mathbb{R}^H$, *output gate* $o\in\mathbb{R}^H$ and *block input* $g\in\mathbb{R}^H$ as
#
# $$
# \begin{align*}
# i = \sigma(a_i) \hspace{2pc}
# f = \sigma(a_f) \hspace{2pc}
# o = \sigma(a_o) \hspace{2pc}
# g = \tanh(a_g)
# \end{align*}
# $$
#
# where $\sigma$ is the sigmoid function and $\tanh$ is the hyperbolic tangent, both applied elementwise.
#
# Finally we compute the next cell state $c_t$ and next hidden state $h_t$ as
#
# $$
# c_{t} = f\odot c_{t-1} + i\odot g \hspace{4pc}
# h_t = o\odot\tanh(c_t)
# $$
#
# where $\odot$ is the elementwise product of vectors.
#
# In the rest of the notebook we will implement the LSTM update rule and apply it to the image captioning task.
#
# In the code, we assume that data is stored in batches so that $X_t \in \mathbb{R}^{N\times D}$, and will work with *transposed* versions of the parameters: $W_x \in \mathbb{R}^{D \times 4H}$, $W_h \in \mathbb{R}^{H\times 4H}$ so that activations $A \in \mathbb{R}^{N\times 4H}$ can be computed efficiently as $A = X_t W_x + H_{t-1} W_h$

# %% [markdown]
# # LSTM: step forward
# Implement the forward pass for a single timestep of an LSTM in the `lstm_step_forward` function in the file `cs231n/rnn_layers.py`. This should be similar to the `rnn_step_forward` function that you implemented above, but using the LSTM update rule instead.
#
# Once you are done, run the following to perform a simple test of your implementation. You should see errors around `1e-8` or less.

# %%
N, D, H = 3, 4, 5
x = np.linspace(-0.4, 1.2, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.3, 0.7, num=N*H).reshape(N, H)
prev_c = np.linspace(-0.4, 0.9, num=N*H).reshape(N, H)
Wx = np.linspace(-2.1, 1.3, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.7, 2.2, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.3, 0.7, num=4*H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

expected_next_h = np.asarray([
    [ 0.24635157,  0.28610883,  0.32240467,  0.35525807,  0.38474904],
    [ 0.49223563,  0.55611431,  0.61507696,  0.66844003,  0.7159181 ],
    [ 0.56735664,  0.66310127,  0.74419266,  0.80889665,  0.858299  ]])
expected_next_c = np.asarray([
    [ 0.32986176,  0.39145139,  0.451556,    0.51014116,  0.56717407],
    [ 0.66382255,  0.76674007,  0.87195994,  0.97902709,  1.08751345],
    [ 0.74192008,  0.90592151,  1.07717006,  1.25120233,  1.42395676]])

print('next_h error: ', rel_error(expected_next_h, next_h))
print('next_c error: ', rel_error(expected_next_c, next_c))
# Out:
# next_h error:  5.70541304045e-09
# next_c error:  5.81431230888e-09

# %% [markdown]
# # LSTM: step backward
# Implement the backward pass for a single LSTM timestep in the function `lstm_step_backward` in the file `cs231n/rnn_layers.py`. Once you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-6` or less.

# %%
np.random.seed(231)

N, D, H = 4, 5, 6
x = np.random.randn(N, D)
prev_h = np.random.randn(N, H)
prev_c = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

dnext_h = np.random.randn(*next_h.shape)
dnext_c = np.random.randn(*next_c.shape)

fx_h = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fh_h = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fc_h = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWx_h = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWh_h = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fb_h = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]

fx_c = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fh_c = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fc_c = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWx_c = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWh_c = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fb_c = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]

num_grad = eval_numerical_gradient_array

dx_num = num_grad(fx_h, x, dnext_h) + num_grad(fx_c, x, dnext_c)
dh_num = num_grad(fh_h, prev_h, dnext_h) + num_grad(fh_c, prev_h, dnext_c)
dc_num = num_grad(fc_h, prev_c, dnext_h) + num_grad(fc_c, prev_c, dnext_c)
dWx_num = num_grad(fWx_h, Wx, dnext_h) + num_grad(fWx_c, Wx, dnext_c)
dWh_num = num_grad(fWh_h, Wh, dnext_h) + num_grad(fWh_c, Wh, dnext_c)
db_num = num_grad(fb_h, b, dnext_h) + num_grad(fb_c, b, dnext_c)

dx, dh, dc, dWx, dWh, db = lstm_step_backward(dnext_h, dnext_c, cache)

print('dx error: ', rel_error(dx_num, dx))
print('dh error: ', rel_error(dh_num, dh))
print('dc error: ', rel_error(dc_num, dc))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  7.48150992821e-10
# dh error:  2.98265410654e-10
# dc error:  7.65076884344e-11
# dWx error:  2.31141332458e-09
# dWh error:  9.79979987222e-08
# db error:  2.74739060696e-10

# %% [markdown]
# # LSTM: forward
# In the function `lstm_forward` in the file `cs231n/rnn_layers.py`, implement the `lstm_forward` function to run an LSTM forward on an entire timeseries of data.
#
# When you are done, run the following to check your implementation. You should see an error around `1e-7`.

# %%
N, D, H, T = 2, 5, 4, 3
x = np.linspace(-0.4, 0.6, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.4, 0.8, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.9, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.3, 0.6, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.2, 0.7, num=4*H)

h, cache = lstm_forward(x, h0, Wx, Wh, b)

expected_h = np.asarray([
 [[ 0.01764008,  0.01823233,  0.01882671,  0.0194232 ],
  [ 0.11287491,  0.12146228,  0.13018446,  0.13902939],
  [ 0.31358768,  0.33338627,  0.35304453,  0.37250975]],
 [[ 0.45767879,  0.4761092,   0.4936887,   0.51041945],
  [ 0.6704845,   0.69350089,  0.71486014,  0.7346449 ],
  [ 0.81733511,  0.83677871,  0.85403753,  0.86935314]]])

print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  8.61053745211e-08

# %% [markdown]
# # LSTM: backward
# Implement the backward pass for an LSTM over an entire timeseries of data in the function `lstm_backward` in the file `cs231n/rnn_layers.py`. When you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-7` or less.

# %%
# from cs231n.rnn_layers import lstm_forward, lstm_backward
np.random.seed(231)

N, D, T, H = 2, 3, 10, 6

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

out, cache = lstm_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

dx, dh0, dWx, dWh, db = lstm_backward(dout, cache)

fx = lambda x: lstm_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: lstm_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: lstm_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: lstm_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: lstm_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  5.58999122439e-09
# dh0 error:  1.03413640397e-08
# dWx error:  2.37032805288e-09
# dWh error:  2.33057825077e-06
# db error:  1.67861205535e-09

# %% [markdown]
# # LSTM captioning model
#
# Now that you have implemented an LSTM, update the implementation of the `loss` method of the `CaptioningRNN` class in the file `cs231n/classifiers/rnn.py` to handle the case where `self.cell_type` is `lstm`. This should require adding less than 10 lines of code.
#
# Once you have done so, run the following to check your implementation. You should see a difference of less than `1e-10`.

# %%
N, D, W, H = 10, 20, 30, 40
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
V = len(word_to_idx)
T = 13

model = CaptioningRNN(word_to_idx,
          input_dim=D,
          wordvec_dim=W,
          hidden_dim=H,
          cell_type='lstm',
          dtype=np.float64)

# Set all model parameters to fixed values
for k, v in model.params.items():
  model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)

features = np.linspace(-0.5, 1.7, num=N*D).reshape(N, D)
captions = (np.arange(N * T) % V).reshape(N, T)

loss, grads = model.loss(features, captions)
expected_loss = 9.82445935443

print('loss: ', loss)
print('expected loss: ', expected_loss)
print('difference: ', abs(loss - expected_loss))
# Out:
# loss:  9.82445935443
# expected loss:  9.82445935443
# difference:  2.26840768391e-12

# %% [markdown]
# # Overfit LSTM captioning model
# Run the following to overfit an LSTM captioning model on the same small dataset as we used for the RNN previously. You should see losses less than 0.5.

# %%
np.random.seed(231)

small_data = load_coco_data(max_train=50)

small_lstm_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256,
          dtype=np.float32,
        )

small_lstm_solver = CaptioningSolver(small_lstm_model, small_data,
           update_rule='adam',
           num_epochs=50,
           batch_size=25,
           optim_config={
             'learning_rate': 5e-3,
           },
           lr_decay=0.995,
           verbose=True, print_every=10,
         )

small_lstm_solver.train()

# Plot the training losses
plt.plot(small_lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# (Iteration 1 / 100) loss: 79.551150
# (Iteration 11 / 100) loss: 43.829080
# (Iteration 21 / 100) loss: 30.062755
# (Iteration 31 / 100) loss: 14.018987
# (Iteration 41 / 100) loss: 5.980247
# (Iteration 51 / 100) loss: 1.841929
# (Iteration 61 / 100) loss: 0.661461
# (Iteration 71 / 100) loss: 0.289665
# (Iteration 81 / 100) loss: 0.258385
# (Iteration 91 / 100) loss: 0.161713

# %% [markdown]
# # LSTM test-time sampling
# Modify the `sample` method of the `CaptioningRNN` class to handle the case where `self.cell_type` is `lstm`. This should take fewer than 10 lines of code.
#
# When you are done run the following to sample from your overfit LSTM model on some training and validation set samples.

# %%
for split in ['train', 'val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])

    sample_captions = small_lstm_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])

    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\nGT:%s' % (split, sample_caption, gt_caption))
        plt.axis('off')
        plt.show()

# %% [markdown]
# # Extra Credit: Train a good captioning model!
# Using the pieces you have implemented in this and the previous notebook, try to train a captioning model that gives decent qualitative results (better than the random garbage you saw with the overfit models) when sampling on the validation set. You can subsample the training set if you want; we just want to see samples on the validation set that are better than random.
#
# In addition to qualitatively evaluating your model by inspecting its results, you can also quantitatively evaluate your model using the BLEU unigram precision metric. We'll give you a small amount of extra credit if you can train a model that achieves a BLEU unigram score of >0.3. BLEU scores range from 0 to 1; the closer to 1, the better. Here's a reference to the [paper](http://www.aclweb.org/anthology/P02-1040.pdf) that introduces BLEU if you're interested in learning more about how it works.
#
# Feel free to use PyTorch or TensorFlow for this section if you'd like to train faster on a GPU... though you can definitely get above 0.3 using your Numpy code. We're providing you the evaluation code that is compatible with the Numpy model as defined above... you should be able to adapt it for TensorFlow/PyTorch if you go that route.

# %%
med_data = load_coco_data(pca_features=True, max_train=1000)

# %%
import nltk
def BLEU_score(gt_caption, sample_caption):
    """
    gt_caption: string, ground-truth caption
    sample_caption: string, your model's predicted caption
    Returns unigram BLEU score.
    """
    reference = [x for x in gt_caption.split(' ') 
                 if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    hypothesis = [x for x in sample_caption.split(' ') 
                  if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis, weights = [1])
    return BLEUscore

def evaluate_model(model):
    """
    model: CaptioningRNN model
    Prints unigram BLEU score averaged over 1000 training and val examples.
    """
    BLEUscores = {}
    for split in ['train', 'val']:
        minibatch = sample_coco_minibatch(med_data, split=split, batch_size=1000)
        gt_captions, features, urls = minibatch
        gt_captions = decode_captions(gt_captions, data['idx_to_word'])

        sample_captions = model.sample(features)
        sample_captions = decode_captions(sample_captions, data['idx_to_word'])

        total_score = 0.0
        for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
            total_score += BLEU_score(gt_caption, sample_caption)

        BLEUscores[split] = total_score / len(sample_captions)

    for split in BLEUscores:
        print('Average BLEU score for %s: %f' % (split, BLEUscores[split]))

# %%
models = {}

# %%
for trial in range(25):
    
    H = int(10**(np.random.uniform(2,3)))
    D = int(10**(np.random.uniform(2,3)))
    lr = 10**(np.random.uniform(-3,-1.5))
    
    print('H: {}, D: {}, lr: {}'.format(H,D,lr))

    lstm_model = CaptioningRNN(
              cell_type='lstm',
              word_to_idx=data['word_to_idx'],
              input_dim=data['train_features'].shape[1],
              hidden_dim=H,
              wordvec_dim=D,
              dtype=np.float32,
            )

    lstm_solver = CaptioningSolver(lstm_model, med_data,
               update_rule='adam',
               num_epochs=5,
               batch_size=25,
               optim_config={
                 'learning_rate': lr,
               },
               lr_decay=0.995)

    lstm_solver.train()
    
    scores = evaluate_model(lstm_model)
    
    models[(H,D,lr)] = (lstm_model, scores)
# Out:
# H: 502, D: 153, lr: 0.017748294527244104
# (Iteration 1 / 200) loss: 80.966459
# (Iteration 11 / 200) loss: 53.724845
# (Iteration 21 / 200) loss: 53.215730
# (Iteration 31 / 200) loss: 41.847423
# (Iteration 41 / 200) loss: 44.046323
# (Iteration 51 / 200) loss: 40.278036
# (Iteration 61 / 200) loss: 36.042187
# (Iteration 71 / 200) loss: 33.502125
# (Iteration 81 / 200) loss: 32.936688
# (Iteration 91 / 200) loss: 34.067306
# (Iteration 101 / 200) loss: 37.255688
# (Iteration 111 / 200) loss: 29.990860
# (Iteration 121 / 200) loss: 27.249315
# (Iteration 131 / 200) loss: 24.797793
# (Iteration 141 / 200) loss: 21.296376
# (Iteration 151 / 200) loss: 26.387771
# (Iteration 161 / 200) loss: 22.980756
# (Iteration 171 / 200) loss: 24.639029
# (Iteration 181 / 200) loss: 21.051496
# (Iteration 191 / 200) loss: 23.038543
# Average BLEU score for train: 0.185426
# Average BLEU score for val: 0.176622
# H: 260, D: 432, lr: 0.018763564350283108
# (Iteration 1 / 200) loss: 80.903229
# (Iteration 11 / 200) loss: 56.645429
# (Iteration 21 / 200) loss: 48.585491
# (Iteration 31 / 200) loss: 42.513457
# (Iteration 41 / 200) loss: 39.270992
# (Iteration 51 / 200) loss: 42.828418
# (Iteration 61 / 200) loss: 39.818439
# (Iteration 71 / 200) loss: 38.979083
# (Iteration 81 / 200) loss: 39.190506
# (Iteration 91 / 200) loss: 33.477822
# (Iteration 101 / 200) loss: 27.548487
# (Iteration 111 / 200) loss: 32.000153
# (Iteration 121 / 200) loss: 28.450439
# (Iteration 131 / 200) loss: 31.037383
# (Iteration 141 / 200) loss: 25.021511
# (Iteration 151 / 200) loss: 26.121311
# (Iteration 161 / 200) loss: 30.786720
# (Iteration 171 / 200) loss: 28.930218
# (Iteration 181 / 200) loss: 22.332009
# (Iteration 191 / 200) loss: 30.701618
# Average BLEU score for train: 0.162086
# Average BLEU score for val: 0.151660
# H: 351, D: 134, lr: 0.00210003030906544
# (Iteration 1 / 200) loss: 78.531826
# (Iteration 11 / 200) loss: 77.239855
# (Iteration 21 / 200) loss: 57.577106
# (Iteration 31 / 200) loss: 50.112515
# (Iteration 41 / 200) loss: 54.202743
# (Iteration 51 / 200) loss: 47.374341
# (Iteration 61 / 200) loss: 48.341075
# (Iteration 71 / 200) loss: 46.123542
# (Iteration 81 / 200) loss: 41.878475
# (Iteration 91 / 200) loss: 39.136892
# (Iteration 101 / 200) loss: 39.999475
# (Iteration 111 / 200) loss: 38.827155
# (Iteration 121 / 200) loss: 35.585490
# (Iteration 131 / 200) loss: 37.006870
# (Iteration 141 / 200) loss: 38.798502
# (Iteration 151 / 200) loss: 38.001107
# (Iteration 161 / 200) loss: 33.867727
# (Iteration 171 / 200) loss: 34.092068
# (Iteration 181 / 200) loss: 32.521639
# (Iteration 191 / 200) loss: 29.594242
# Average BLEU score for train: 0.248207
# Average BLEU score for val: 0.208425
# H: 204, D: 320, lr: 0.0011166263058839262
# (Iteration 1 / 200) loss: 78.063804
# (Iteration 11 / 200) loss: 83.636643
# (Iteration 21 / 200) loss: 68.784204
# (Iteration 31 / 200) loss: 61.502006
# (Iteration 41 / 200) loss: 57.339600
# (Iteration 51 / 200) loss: 53.399330
# (Iteration 61 / 200) loss: 51.927361
# (Iteration 71 / 200) loss: 52.742179
# (Iteration 81 / 200) loss: 49.828111
# (Iteration 91 / 200) loss: 47.473899
# (Iteration 101 / 200) loss: 49.032324
# (Iteration 111 / 200) loss: 47.157806
# (Iteration 121 / 200) loss: 46.373239
# (Iteration 131 / 200) loss: 43.788347
# (Iteration 141 / 200) loss: 41.770384
# (Iteration 151 / 200) loss: 44.642809
# (Iteration 161 / 200) loss: 41.602920
# (Iteration 171 / 200) loss: 40.197514
# (Iteration 181 / 200) loss: 41.821128
# (Iteration 191 / 200) loss: 38.479458
# Average BLEU score for train: 0.129747
# Average BLEU score for val: 0.119404
# H: 122, D: 872, lr: 0.014862028312320403
# (Iteration 1 / 200) loss: 82.422329
# (Iteration 11 / 200) loss: 49.155249
# (Iteration 21 / 200) loss: 47.863206
# (Iteration 31 / 200) loss: 44.442301
# (Iteration 41 / 200) loss: 41.277432
# (Iteration 51 / 200) loss: 41.297754
# (Iteration 61 / 200) loss: 41.375075
# (Iteration 71 / 200) loss: 37.402118
# (Iteration 81 / 200) loss: 34.288983
# (Iteration 91 / 200) loss: 31.982435
# (Iteration 101 / 200) loss: 35.680548
# (Iteration 111 / 200) loss: 34.676917
# (Iteration 121 / 200) loss: 33.065331
# (Iteration 131 / 200) loss: 32.145154
# (Iteration 141 / 200) loss: 27.742367
# (Iteration 151 / 200) loss: 28.786075
# (Iteration 161 / 200) loss: 26.470816
# (Iteration 171 / 200) loss: 32.907359
# (Iteration 181 / 200) loss: 28.933905
# (Iteration 191 / 200) loss: 31.527314
# Average BLEU score for train: 0.061431
# Average BLEU score for val: 0.072219
# H: 154, D: 445, lr: 0.0023822452125362957
# (Iteration 1 / 200) loss: 76.495994
# (Iteration 11 / 200) loss: 75.739609
# (Iteration 21 / 200) loss: 57.584478
# (Iteration 31 / 200) loss: 56.435974
# (Iteration 41 / 200) loss: 53.663691
# (Iteration 51 / 200) loss: 53.366550
# (Iteration 61 / 200) loss: 54.232051
# (Iteration 71 / 200) loss: 48.123290
# (Iteration 81 / 200) loss: 43.414377
# (Iteration 91 / 200) loss: 43.881460
# (Iteration 101 / 200) loss: 44.951307
# (Iteration 111 / 200) loss: 43.293097
# (Iteration 121 / 200) loss: 41.434683
# (Iteration 131 / 200) loss: 37.867515
# (Iteration 141 / 200) loss: 36.869529
# (Iteration 151 / 200) loss: 35.183010
# (Iteration 161 / 200) loss: 41.321927
# (Iteration 171 / 200) loss: 36.910505
# (Iteration 181 / 200) loss: 34.019583
# (Iteration 191 / 200) loss: 32.855054
# Average BLEU score for train: 0.164343
# Average BLEU score for val: 0.142613
# H: 819, D: 176, lr: 0.00349832018780637
# (Iteration 1 / 200) loss: 76.441172
# (Iteration 11 / 200) loss: 58.026129
# (Iteration 21 / 200) loss: 51.519098
# (Iteration 31 / 200) loss: 50.172136
# (Iteration 41 / 200) loss: 49.983743
# (Iteration 51 / 200) loss: 40.706882
# (Iteration 61 / 200) loss: 45.955964
# (Iteration 71 / 200) loss: 38.182654
# (Iteration 81 / 200) loss: 38.338823
# (Iteration 91 / 200) loss: 31.352705
# (Iteration 101 / 200) loss: 29.365969
# (Iteration 111 / 200) loss: 25.520817
# (Iteration 121 / 200) loss: 31.868422
# (Iteration 131 / 200) loss: 26.772591
# (Iteration 141 / 200) loss: 27.684093
# (Iteration 151 / 200) loss: 27.439995
# (Iteration 161 / 200) loss: 22.743970
# (Iteration 171 / 200) loss: 21.669326
# (Iteration 181 / 200) loss: 19.152355
# (Iteration 191 / 200) loss: 17.731849
# Average BLEU score for train: 0.311841
# Average BLEU score for val: 0.204208
# H: 104, D: 372, lr: 0.010965806578450678
# (Iteration 1 / 200) loss: 79.205767
# (Iteration 11 / 200) loss: 56.176824
# (Iteration 21 / 200) loss: 49.340510
# (Iteration 31 / 200) loss: 47.142992
# (Iteration 41 / 200) loss: 46.604465
# (Iteration 51 / 200) loss: 40.235333
# (Iteration 61 / 200) loss: 41.181969
# (Iteration 71 / 200) loss: 38.635432
# (Iteration 81 / 200) loss: 38.519575
# (Iteration 91 / 200) loss: 43.163080
# (Iteration 101 / 200) loss: 35.505392
# (Iteration 111 / 200) loss: 34.033173
# (Iteration 121 / 200) loss: 33.722030
# (Iteration 131 / 200) loss: 38.851042
# (Iteration 141 / 200) loss: 38.004281
# (Iteration 151 / 200) loss: 32.631910
# (Iteration 161 / 200) loss: 30.578634
# (Iteration 171 / 200) loss: 31.978930
# (Iteration 181 / 200) loss: 29.769552
# (Iteration 191 / 200) loss: 27.988899
# Average BLEU score for train: 0.177216
# Average BLEU score for val: 0.168557
# H: 106, D: 715, lr: 0.0249147528732706
# (Iteration 1 / 200) loss: 74.924501
# (Iteration 11 / 200) loss: 49.196870
# (Iteration 21 / 200) loss: 48.568667
# (Iteration 31 / 200) loss: 43.580158
# (Iteration 41 / 200) loss: 41.141819
# (Iteration 51 / 200) loss: 44.818896
# (Iteration 61 / 200) loss: 36.642784
# (Iteration 71 / 200) loss: 43.006463
# (Iteration 81 / 200) loss: 34.371715
# (Iteration 91 / 200) loss: 36.096585
# (Iteration 101 / 200) loss: 38.885022
# (Iteration 111 / 200) loss: 34.555340
# (Iteration 121 / 200) loss: 40.475342
# (Iteration 131 / 200) loss: 35.027644
# (Iteration 141 / 200) loss: 32.560046
# (Iteration 151 / 200) loss: 35.444464
# (Iteration 161 / 200) loss: 36.625548
# (Iteration 171 / 200) loss: 32.273426
# (Iteration 181 / 200) loss: 35.004310
# (Iteration 191 / 200) loss: 27.761691
# Average BLEU score for train: 0.135988
# Average BLEU score for val: 0.138298
# H: 137, D: 140, lr: 0.009640452296886178
# (Iteration 1 / 200) loss: 78.291890
# (Iteration 11 / 200) loss: 51.277374
# (Iteration 21 / 200) loss: 54.518304
# (Iteration 31 / 200) loss: 48.028196
# (Iteration 41 / 200) loss: 40.175984
# (Iteration 51 / 200) loss: 44.473121
# (Iteration 61 / 200) loss: 41.299833
# (Iteration 71 / 200) loss: 38.562179
# (Iteration 81 / 200) loss: 41.451418
# (Iteration 91 / 200) loss: 39.853985
# (Iteration 101 / 200) loss: 37.828412
# (Iteration 111 / 200) loss: 40.245849
# (Iteration 121 / 200) loss: 36.182799
# (Iteration 131 / 200) loss: 34.458500
# (Iteration 141 / 200) loss: 36.418151
# (Iteration 151 / 200) loss: 34.878452
# (Iteration 161 / 200) loss: 31.205969
# (Iteration 171 / 200) loss: 33.425332
# (Iteration 181 / 200) loss: 34.881833
# (Iteration 191 / 200) loss: 31.104259
# Average BLEU score for train: 0.198137
# Average BLEU score for val: 0.194005
# H: 510, D: 384, lr: 0.0023494550111890495
# (Iteration 1 / 200) loss: 76.288777
# (Iteration 11 / 200) loss: 62.390343
# (Iteration 21 / 200) loss: 50.295658
# (Iteration 31 / 200) loss: 54.003336
# (Iteration 41 / 200) loss: 50.145594
# (Iteration 51 / 200) loss: 48.475347
# (Iteration 61 / 200) loss: 40.660522
# (Iteration 71 / 200) loss: 41.655007
# (Iteration 81 / 200) loss: 35.480049
# (Iteration 91 / 200) loss: 39.402934
# (Iteration 101 / 200) loss: 37.272678
# (Iteration 111 / 200) loss: 32.667703
# (Iteration 121 / 200) loss: 34.509173
# (Iteration 131 / 200) loss: 32.295355
# (Iteration 141 / 200) loss: 29.690350
# (Iteration 151 / 200) loss: 27.597838
# (Iteration 161 / 200) loss: 27.587506
# (Iteration 171 / 200) loss: 24.113187
# (Iteration 181 / 200) loss: 24.656165
# (Iteration 191 / 200) loss: 23.447426
# Average BLEU score for train: 0.286093
# Average BLEU score for val: 0.209031
# H: 459, D: 500, lr: 0.0013030483807230226
# (Iteration 1 / 200) loss: 80.379776
# (Iteration 11 / 200) loss: 73.499784
# (Iteration 21 / 200) loss: 55.324499
# (Iteration 31 / 200) loss: 53.070902
# (Iteration 41 / 200) loss: 52.770329
# (Iteration 51 / 200) loss: 52.547509
# (Iteration 61 / 200) loss: 47.677233
# (Iteration 71 / 200) loss: 49.529460
# (Iteration 81 / 200) loss: 42.492680
# (Iteration 91 / 200) loss: 43.329964
# (Iteration 101 / 200) loss: 42.629273
# (Iteration 111 / 200) loss: 37.021359
# (Iteration 121 / 200) loss: 36.147593
# (Iteration 131 / 200) loss: 38.208841
# (Iteration 141 / 200) loss: 34.966565
# (Iteration 151 / 200) loss: 32.059102
# (Iteration 161 / 200) loss: 31.085894
# (Iteration 171 / 200) loss: 30.300665
# (Iteration 181 / 200) loss: 27.627511
# (Iteration 191 / 200) loss: 29.165560
# Average BLEU score for train: 0.213490
# Average BLEU score for val: 0.161625
# H: 938, D: 485, lr: 0.001925442313366641
# (Iteration 1 / 200) loss: 81.643287
# (Iteration 11 / 200) loss: 59.775952
# (Iteration 21 / 200) loss: 54.773635
# (Iteration 31 / 200) loss: 46.389910
# (Iteration 41 / 200) loss: 44.527386
# (Iteration 51 / 200) loss: 41.851594
# (Iteration 61 / 200) loss: 45.283936
# (Iteration 71 / 200) loss: 33.671925
# (Iteration 81 / 200) loss: 40.904486
# (Iteration 91 / 200) loss: 39.181750
# (Iteration 101 / 200) loss: 31.768329
# (Iteration 111 / 200) loss: 33.209111
# (Iteration 121 / 200) loss: 30.965729
# (Iteration 131 / 200) loss: 28.494922
# (Iteration 141 / 200) loss: 25.317948
# (Iteration 151 / 200) loss: 24.850495
# (Iteration 161 / 200) loss: 19.645802
# (Iteration 171 / 200) loss: 19.596054
# (Iteration 181 / 200) loss: 21.737359
# (Iteration 191 / 200) loss: 24.833862
# Average BLEU score for train: 0.350763
# Average BLEU score for val: 0.219245
# H: 336, D: 374, lr: 0.0017108995592329344
# (Iteration 1 / 200) loss: 74.462267
# (Iteration 11 / 200) loss: 76.524482
# (Iteration 21 / 200) loss: 62.123495
# (Iteration 31 / 200) loss: 56.471406
# (Iteration 41 / 200) loss: 54.084705
# (Iteration 51 / 200) loss: 50.989565
# (Iteration 61 / 200) loss: 51.291419
# (Iteration 71 / 200) loss: 47.116919
# (Iteration 81 / 200) loss: 48.560714
# (Iteration 91 / 200) loss: 43.507084
# (Iteration 101 / 200) loss: 37.554033
# (Iteration 111 / 200) loss: 37.426475
# (Iteration 121 / 200) loss: 36.394812
# (Iteration 131 / 200) loss: 36.732236
# (Iteration 141 / 200) loss: 36.642391
# (Iteration 151 / 200) loss: 31.460417
# (Iteration 161 / 200) loss: 29.250554
# (Iteration 171 / 200) loss: 33.641937
# (Iteration 181 / 200) loss: 31.222599
# (Iteration 191 / 200) loss: 33.977045
# Average BLEU score for train: 0.205087
# Average BLEU score for val: 0.159320
# H: 406, D: 898, lr: 0.0012363704491957512
# (Iteration 1 / 200) loss: 79.077483
# (Iteration 11 / 200) loss: 72.664593
# (Iteration 21 / 200) loss: 59.619838
# (Iteration 31 / 200) loss: 51.706030
# (Iteration 41 / 200) loss: 53.832483
# (Iteration 51 / 200) loss: 49.953038
# (Iteration 61 / 200) loss: 50.957663
# (Iteration 71 / 200) loss: 47.133750
# (Iteration 81 / 200) loss: 40.071648
# (Iteration 91 / 200) loss: 39.722760
# (Iteration 101 / 200) loss: 43.821411
# (Iteration 111 / 200) loss: 37.640812
# (Iteration 121 / 200) loss: 36.443629
# (Iteration 131 / 200) loss: 34.595404
# (Iteration 141 / 200) loss: 31.211752
# (Iteration 151 / 200) loss: 32.036470
# (Iteration 161 / 200) loss: 30.798219
# (Iteration 171 / 200) loss: 34.772476
# (Iteration 181 / 200) loss: 34.223567
# (Iteration 191 / 200) loss: 30.828135
# Average BLEU score for train: 0.174776
# Average BLEU score for val: 0.142709
# H: 186, D: 850, lr: 0.010035342988499415
# (Iteration 1 / 200) loss: 74.726047
# (Iteration 11 / 200) loss: 58.291892
# (Iteration 21 / 200) loss: 48.730379
# (Iteration 31 / 200) loss: 42.444155
# (Iteration 41 / 200) loss: 42.454049
# (Iteration 51 / 200) loss: 39.688133
# (Iteration 61 / 200) loss: 39.200863
# (Iteration 71 / 200) loss: 40.514588
# (Iteration 81 / 200) loss: 36.521317
# (Iteration 91 / 200) loss: 36.856206
# (Iteration 101 / 200) loss: 32.505357
# (Iteration 111 / 200) loss: 34.214855
# (Iteration 121 / 200) loss: 33.166141
# (Iteration 131 / 200) loss: 29.637824
# (Iteration 141 / 200) loss: 29.085002
# (Iteration 151 / 200) loss: 27.360505
# (Iteration 161 / 200) loss: 25.979679
# (Iteration 171 / 200) loss: 26.206007
# (Iteration 181 / 200) loss: 26.466681
# (Iteration 191 / 200) loss: 23.877922
# Average BLEU score for train: 0.155845
# Average BLEU score for val: 0.156940
# H: 760, D: 192, lr: 0.010695756103393858
# (Iteration 1 / 200) loss: 77.474878
# (Iteration 11 / 200) loss: 54.867544
# (Iteration 21 / 200) loss: 49.827425
# (Iteration 31 / 200) loss: 43.197450
# (Iteration 41 / 200) loss: 34.714812
# (Iteration 51 / 200) loss: 39.170377
# (Iteration 61 / 200) loss: 39.150801
# (Iteration 71 / 200) loss: 35.356697
# (Iteration 81 / 200) loss: 32.225386
# (Iteration 91 / 200) loss: 34.105525
# (Iteration 101 / 200) loss: 27.098971
# (Iteration 111 / 200) loss: 25.431492
# (Iteration 121 / 200) loss: 27.378399
# (Iteration 131 / 200) loss: 25.998861
# (Iteration 141 / 200) loss: 24.791393
# (Iteration 151 / 200) loss: 27.117442
# (Iteration 161 / 200) loss: 17.114147
# (Iteration 171 / 200) loss: 18.517203
# (Iteration 181 / 200) loss: 17.643122
# (Iteration 191 / 200) loss: 15.895267
# Average BLEU score for train: 0.189005
# Average BLEU score for val: 0.174617
# H: 189, D: 348, lr: 0.020778236286484116
# (Iteration 1 / 200) loss: 80.530622
# (Iteration 11 / 200) loss: 55.229978
# (Iteration 21 / 200) loss: 50.457756
# (Iteration 31 / 200) loss: 45.883533
# (Iteration 41 / 200) loss: 41.310529
# (Iteration 51 / 200) loss: 39.383393
# (Iteration 61 / 200) loss: 40.420572
# (Iteration 71 / 200) loss: 41.496885
# (Iteration 81 / 200) loss: 30.969227
# (Iteration 91 / 200) loss: 31.544956
# (Iteration 101 / 200) loss: 33.717297
# (Iteration 111 / 200) loss: 30.389996
# (Iteration 121 / 200) loss: 28.344663
# (Iteration 131 / 200) loss: 32.887499
# (Iteration 141 / 200) loss: 26.486954
# (Iteration 151 / 200) loss: 27.940381
# (Iteration 161 / 200) loss: 28.055497
# (Iteration 171 / 200) loss: 25.446740
# (Iteration 181 / 200) loss: 22.916466
# (Iteration 191 / 200) loss: 25.378494
# Average BLEU score for train: 0.151442
# Average BLEU score for val: 0.148671
# H: 122, D: 532, lr: 0.0037778941453869208
# (Iteration 1 / 200) loss: 77.691097
# (Iteration 11 / 200) loss: 63.884160
# (Iteration 21 / 200) loss: 55.324375
# (Iteration 31 / 200) loss: 52.505986
# (Iteration 41 / 200) loss: 48.804412
# (Iteration 51 / 200) loss: 50.876037
# (Iteration 61 / 200) loss: 43.681832
# (Iteration 71 / 200) loss: 45.427137
# (Iteration 81 / 200) loss: 41.967148
# (Iteration 91 / 200) loss: 39.489342
# (Iteration 101 / 200) loss: 37.528352
# (Iteration 111 / 200) loss: 35.153954
# (Iteration 121 / 200) loss: 39.007947
# (Iteration 131 / 200) loss: 36.593234
# (Iteration 141 / 200) loss: 34.142436
# (Iteration 151 / 200) loss: 40.420269
# (Iteration 161 / 200) loss: 36.229277
# (Iteration 171 / 200) loss: 32.842169
# (Iteration 181 / 200) loss: 33.523574
# (Iteration 191 / 200) loss: 35.002723
# Average BLEU score for train: 0.142884
# Average BLEU score for val: 0.123340
# H: 205, D: 200, lr: 0.02929192224161195
# (Iteration 1 / 200) loss: 77.156452
# (Iteration 11 / 200) loss: 56.001138
# (Iteration 21 / 200) loss: 48.259954
# (Iteration 31 / 200) loss: 44.172831
# (Iteration 41 / 200) loss: 45.214521
# (Iteration 51 / 200) loss: 44.674659
# (Iteration 61 / 200) loss: 42.031713
# (Iteration 71 / 200) loss: 35.816534
# (Iteration 81 / 200) loss: 38.732691
# (Iteration 91 / 200) loss: 34.684648
# (Iteration 101 / 200) loss: 40.366962
# (Iteration 111 / 200) loss: 34.885300
# (Iteration 121 / 200) loss: 29.153557
# (Iteration 131 / 200) loss: 28.464097
# (Iteration 141 / 200) loss: 28.569561
# (Iteration 151 / 200) loss: 36.592972
# (Iteration 161 / 200) loss: 28.958199
# (Iteration 171 / 200) loss: 29.355730
# (Iteration 181 / 200) loss: 28.184924
# (Iteration 191 / 200) loss: 30.605795
# Average BLEU score for train: 0.105746
# Average BLEU score for val: 0.107991
# H: 185, D: 979, lr: 0.0011379802963830527
# (Iteration 1 / 200) loss: 79.080722
# (Iteration 11 / 200) loss: 76.528167
# (Iteration 21 / 200) loss: 66.219530
# (Iteration 31 / 200) loss: 61.954736
# (Iteration 41 / 200) loss: 54.903186
# (Iteration 51 / 200) loss: 53.673223
# (Iteration 61 / 200) loss: 48.693809
# (Iteration 71 / 200) loss: 50.048188
# (Iteration 81 / 200) loss: 50.371674
# (Iteration 91 / 200) loss: 49.799994
# (Iteration 101 / 200) loss: 44.661242
# (Iteration 111 / 200) loss: 43.919638
# (Iteration 121 / 200) loss: 43.757704
# (Iteration 131 / 200) loss: 39.459390
# (Iteration 141 / 200) loss: 38.268403
# (Iteration 151 / 200) loss: 40.876505
# (Iteration 161 / 200) loss: 39.135278
# (Iteration 171 / 200) loss: 39.398653
# (Iteration 181 / 200) loss: 38.788438
# (Iteration 191 / 200) loss: 38.845709
# Average BLEU score for train: 0.094790
# Average BLEU score for val: 0.085131
# H: 232, D: 171, lr: 0.021312427092262217
# (Iteration 1 / 200) loss: 79.417521
# (Iteration 11 / 200) loss: 57.735292
# (Iteration 21 / 200) loss: 47.850413
# (Iteration 31 / 200) loss: 42.459139
# (Iteration 41 / 200) loss: 42.224449
# (Iteration 51 / 200) loss: 40.374029
# (Iteration 61 / 200) loss: 39.919842
# (Iteration 71 / 200) loss: 39.568212
# (Iteration 81 / 200) loss: 29.917731
# (Iteration 91 / 200) loss: 31.850423
# (Iteration 101 / 200) loss: 37.425074
# (Iteration 111 / 200) loss: 33.213360
# (Iteration 121 / 200) loss: 30.825910
# (Iteration 131 / 200) loss: 28.189956
# (Iteration 141 / 200) loss: 28.865598
# (Iteration 151 / 200) loss: 26.783234
# (Iteration 161 / 200) loss: 26.299540
# (Iteration 171 / 200) loss: 27.197712
# (Iteration 181 / 200) loss: 24.174257
# (Iteration 191 / 200) loss: 27.130376
# Average BLEU score for train: 0.147816
# Average BLEU score for val: 0.143978
# H: 571, D: 827, lr: 0.010620950702256465
# (Iteration 1 / 200) loss: 76.949256
# (Iteration 11 / 200) loss: 60.189645
# (Iteration 21 / 200) loss: 47.682561
# (Iteration 31 / 200) loss: 46.319501
# (Iteration 41 / 200) loss: 42.107933
# (Iteration 51 / 200) loss: 38.467083
# (Iteration 61 / 200) loss: 33.929830
# (Iteration 71 / 200) loss: 38.668718
# (Iteration 81 / 200) loss: 32.075127
# (Iteration 91 / 200) loss: 32.022346
# (Iteration 101 / 200) loss: 30.872413
# (Iteration 111 / 200) loss: 28.997970
# (Iteration 121 / 200) loss: 24.499339
# (Iteration 131 / 200) loss: 20.814357
# (Iteration 141 / 200) loss: 24.783949
# (Iteration 151 / 200) loss: 25.674397
# (Iteration 161 / 200) loss: 22.186829
# (Iteration 171 / 200) loss: 18.882632
# (Iteration 181 / 200) loss: 24.798133
# (Iteration 191 / 200) loss: 17.558654
# Average BLEU score for train: 0.187277
# Average BLEU score for val: 0.173034
# H: 194, D: 194, lr: 0.013268014109046709
# (Iteration 1 / 200) loss: 78.854885
# (Iteration 11 / 200) loss: 56.044252
# (Iteration 21 / 200) loss: 52.653657
# (Iteration 31 / 200) loss: 44.385867
# (Iteration 41 / 200) loss: 43.591842
# (Iteration 51 / 200) loss: 42.977995
# (Iteration 61 / 200) loss: 38.826580
# (Iteration 71 / 200) loss: 37.065046
# (Iteration 81 / 200) loss: 38.334683
# (Iteration 91 / 200) loss: 35.337615
# (Iteration 101 / 200) loss: 31.776918
# (Iteration 111 / 200) loss: 31.414831
# (Iteration 121 / 200) loss: 29.435134
# (Iteration 131 / 200) loss: 29.574179
# (Iteration 141 / 200) loss: 26.866842
# (Iteration 151 / 200) loss: 26.996526
# (Iteration 161 / 200) loss: 28.210672
# (Iteration 171 / 200) loss: 25.258358
# (Iteration 181 / 200) loss: 24.750643
# (Iteration 191 / 200) loss: 24.071030
# Average BLEU score for train: 0.196441
# Average BLEU score for val: 0.186456
# H: 147, D: 248, lr: 0.0019241922140228146
# (Iteration 1 / 200) loss: 77.193890
# (Iteration 11 / 200) loss: 75.972801
# (Iteration 21 / 200) loss: 59.898748
# (Iteration 31 / 200) loss: 54.267968
# (Iteration 41 / 200) loss: 55.334391
# (Iteration 51 / 200) loss: 52.152668
# (Iteration 61 / 200) loss: 53.776854
# (Iteration 71 / 200) loss: 50.243772
# (Iteration 81 / 200) loss: 48.462318
# (Iteration 91 / 200) loss: 47.619371
# (Iteration 101 / 200) loss: 46.478519
# (Iteration 111 / 200) loss: 43.339198
# (Iteration 121 / 200) loss: 42.932945
# (Iteration 131 / 200) loss: 41.531177
# (Iteration 141 / 200) loss: 41.750680
# (Iteration 151 / 200) loss: 37.717011
# (Iteration 161 / 200) loss: 37.349877
# (Iteration 171 / 200) loss: 41.320608
# (Iteration 181 / 200) loss: 32.549998
# (Iteration 191 / 200) loss: 39.716170
# Average BLEU score for train: 0.170468
# Average BLEU score for val: 0.151009

# %%
from pylab import *
from mpl_toolkits.mplot3d import Axes3D

xs = []
ys = []
zs = []
cs = []

for k,v in models.items():
    
    H, D, lr = k
    _, scores = v
    score = scores['val']
    
    xs.append(H)
    ys.append(D)
    zs.append(lr)
    cs.append(score)
    

fig = plt.figure(figsize=(15,15))

ax = fig.add_subplot(111,projection='3d')

colors = cm.hsv(np.asarray(cs)/max(cs))

colmap = cm.ScalarMappable(cmap=cm.hsv)
colmap.set_array(cs)

yg = ax.scatter(xs, ys, zs, c=colors, marker='o')
cb = fig.colorbar(colmap)

ax.set_xlabel('H')
ax.set_ylabel('D')
ax.set_zlabel('lr')

plt.show()

# %%
large_data = load_coco_data(pca_features=True, max_train=10000)

lstm_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256,
          dtype=np.float32,
        )

lstm_solver = CaptioningSolver(lstm_model, large_data,
           update_rule='adam',
           num_epochs=50,
           batch_size=25,
           optim_config={
             'learning_rate': 5e-3,
           },
           lr_decay=0.995,
           verbose=True, print_every=100,
         )

lstm_solver.train()

evaluate_model(lstm_model)

# Plot the training losses
plt.plot(lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# (Iteration 1 / 20000) loss: 77.274877
# (Iteration 101 / 20000) loss: 39.111525
# (Iteration 201 / 20000) loss: 35.769537
# (Iteration 301 / 20000) loss: 33.496295
# (Iteration 401 / 20000) loss: 31.972642
# (Iteration 501 / 20000) loss: 27.902606
# (Iteration 601 / 20000) loss: 27.688838
# (Iteration 701 / 20000) loss: 29.259660
# (Iteration 801 / 20000) loss: 23.734904
# (Iteration 901 / 20000) loss: 28.675882
# (Iteration 1001 / 20000) loss: 23.346387
# (Iteration 1101 / 20000) loss: 25.807961
# (Iteration 1201 / 20000) loss: 22.129602
# (Iteration 1301 / 20000) loss: 23.322012
# (Iteration 1401 / 20000) loss: 27.031030
# (Iteration 1501 / 20000) loss: 26.606425
# (Iteration 1601 / 20000) loss: 21.842893
# (Iteration 1701 / 20000) loss: 25.072232
# (Iteration 1801 / 20000) loss: 24.022200
# (Iteration 1901 / 20000) loss: 22.056460
# (Iteration 2001 / 20000) loss: 17.862409
# (Iteration 2101 / 20000) loss: 24.262759
# (Iteration 2201 / 20000) loss: 19.759277
# (Iteration 2301 / 20000) loss: 20.906104
# (Iteration 2401 / 20000) loss: 19.880320
# (Iteration 2501 / 20000) loss: 19.203287
# (Iteration 2601 / 20000) loss: 18.031142
# (Iteration 2701 / 20000) loss: 23.130084
# (Iteration 2801 / 20000) loss: 21.028357
# (Iteration 2901 / 20000) loss: 18.692072
# (Iteration 3001 / 20000) loss: 17.910861
# (Iteration 3101 / 20000) loss: 24.169476
# (Iteration 3201 / 20000) loss: 17.070845
# (Iteration 3301 / 20000) loss: 16.234729
# (Iteration 3401 / 20000) loss: 18.563281
# (Iteration 3501 / 20000) loss: 22.511869
# (Iteration 3601 / 20000) loss: 18.562063
# (Iteration 3701 / 20000) loss: 20.318241
# (Iteration 3801 / 20000) loss: 17.702868
# (Iteration 3901 / 20000) loss: 18.707599
# (Iteration 4001 / 20000) loss: 17.487570
# (Iteration 4101 / 20000) loss: 16.729076
# (Iteration 4201 / 20000) loss: 14.636079
# (Iteration 4301 / 20000) loss: 20.857297
# (Iteration 4401 / 20000) loss: 16.371155
# (Iteration 4501 / 20000) loss: 15.116119
# (Iteration 4601 / 20000) loss: 18.532369
# (Iteration 4701 / 20000) loss: 19.164364
# (Iteration 4801 / 20000) loss: 16.332900
# (Iteration 4901 / 20000) loss: 16.817557
# (Iteration 5001 / 20000) loss: 17.642844
# (Iteration 5101 / 20000) loss: 18.419527
# (Iteration 5201 / 20000) loss: 21.393702
# (Iteration 5301 / 20000) loss: 15.163352
# (Iteration 5401 / 20000) loss: 16.894489
# (Iteration 5501 / 20000) loss: 18.058261
# (Iteration 5601 / 20000) loss: 16.182084
# (Iteration 5701 / 20000) loss: 16.031153
# (Iteration 5801 / 20000) loss: 16.491725
# (Iteration 5901 / 20000) loss: 15.754679
# (Iteration 6001 / 20000) loss: 17.725338
# (Iteration 6101 / 20000) loss: 13.693877
# (Iteration 6201 / 20000) loss: 16.439866
# (Iteration 6301 / 20000) loss: 18.511475
# (Iteration 6401 / 20000) loss: 17.569878
# (Iteration 6501 / 20000) loss: 15.355748
# (Iteration 6601 / 20000) loss: 14.335968
# (Iteration 6701 / 20000) loss: 15.300809
# (Iteration 6801 / 20000) loss: 15.440776
# (Iteration 6901 / 20000) loss: 13.764644
# (Iteration 7001 / 20000) loss: 14.422518
# (Iteration 7101 / 20000) loss: 13.418035
# (Iteration 7201 / 20000) loss: 16.986538
# (Iteration 7301 / 20000) loss: 11.973660
# (Iteration 7401 / 20000) loss: 16.643489
# (Iteration 7501 / 20000) loss: 15.649490
# (Iteration 7601 / 20000) loss: 14.962913
# (Iteration 7701 / 20000) loss: 14.918789
# (Iteration 7801 / 20000) loss: 15.787567
# (Iteration 7901 / 20000) loss: 15.627605
# (Iteration 8001 / 20000) loss: 12.996532
# (Iteration 8101 / 20000) loss: 16.157274
# (Iteration 8201 / 20000) loss: 17.704098
# (Iteration 8301 / 20000) loss: 16.110085
# (Iteration 8401 / 20000) loss: 13.173427
# (Iteration 8501 / 20000) loss: 15.896121
# (Iteration 8601 / 20000) loss: 14.836589
# (Iteration 8701 / 20000) loss: 12.748297
# (Iteration 8801 / 20000) loss: 14.356417
# (Iteration 8901 / 20000) loss: 14.252883
# (Iteration 9001 / 20000) loss: 14.935512
# (Iteration 9101 / 20000) loss: 14.518972
# (Iteration 9201 / 20000) loss: 15.834961
# (Iteration 9301 / 20000) loss: 13.181650
# (Iteration 9401 / 20000) loss: 12.722148
# (Iteration 9501 / 20000) loss: 15.820293
# (Iteration 9601 / 20000) loss: 15.155012
# (Iteration 9701 / 20000) loss: 13.420878
# (Iteration 9801 / 20000) loss: 15.394513
# (Iteration 9901 / 20000) loss: 12.238102
# (Iteration 10001 / 20000) loss: 14.635241
# (Iteration 10101 / 20000) loss: 13.352183
# (Iteration 10201 / 20000) loss: 12.539420
# (Iteration 10301 / 20000) loss: 12.863097
# (Iteration 10401 / 20000) loss: 12.434249
# (Iteration 10501 / 20000) loss: 14.034887
# (Iteration 10601 / 20000) loss: 13.576102
# (Iteration 10701 / 20000) loss: 12.734935
# (Iteration 10801 / 20000) loss: 12.021704
# (Iteration 10901 / 20000) loss: 13.785863
# (Iteration 11001 / 20000) loss: 15.005675
# (Iteration 11101 / 20000) loss: 11.071103
# (Iteration 11201 / 20000) loss: 10.367409
# (Iteration 11301 / 20000) loss: 15.746320
# (Iteration 11401 / 20000) loss: 12.602627
# (Iteration 11501 / 20000) loss: 14.093295
# (Iteration 11601 / 20000) loss: 13.262211
# (Iteration 11701 / 20000) loss: 14.606769
# (Iteration 11801 / 20000) loss: 13.810079
# (Iteration 11901 / 20000) loss: 15.200269
# (Iteration 12001 / 20000) loss: 12.211003
# (Iteration 12101 / 20000) loss: 13.549306
# (Iteration 12201 / 20000) loss: 12.298621
# (Iteration 12301 / 20000) loss: 13.925727
# (Iteration 12401 / 20000) loss: 14.194916
# (Iteration 12501 / 20000) loss: 13.516366
# (Iteration 12601 / 20000) loss: 14.489825
# (Iteration 12701 / 20000) loss: 15.110311
# (Iteration 12801 / 20000) loss: 14.550579
# (Iteration 12901 / 20000) loss: 14.559258
# (Iteration 13001 / 20000) loss: 14.164683
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-cfe1a25ec5de> in <module>()
#      21          )
#      22
# ---> 23 lstm_solver.train()
#      24
#      25 evaluate_model(lstm_model)
#
# /home/heerad/dev/cs231n/assignment3/cs231n/captioning_solver.py in train(self)
#     213
#     214         for t in range(num_iterations):
# --> 215             self._step()
#     216
#     217             # Maybe print training loss
#
# /home/heerad/dev/cs231n/assignment3/cs231n/captioning_solver.py in _step(self)
#     149
#     150         # Compute loss and gradient
# --> 151         loss, grads = self.model.loss(features, captions)
#     152         self.loss_history.append(loss)
#     153
#
# /home/heerad/dev/cs231n/assignment3/cs231n/classifiers/rnn.py in loss(self, features, captions)
#     170             dembeds, dh0, grads['Wx'], grads['Wh'], grads['b'] = rnn_backward(dh, rnn_cache)
#     171         elif self.cell_type == 'lstm':
# --> 172             dembeds, dh0, grads['Wx'], grads['Wh'], grads['b'] = lstm_backward(dh, lstm_cache)
#     173
#     174         grads['W_embed'] = word_embedding_backward(dembeds, embed_cache)
#
# /home/heerad/dev/cs231n/assignment3/cs231n/rnn_layers.py in lstm_backward(dh, cache)
#     428
#     429     for t in reversed(range(T)):
# --> 430         dx[:,t,:], dnext_h, dnext_c, dWx_add, dWh_add, db_add = lstm_step_backward(dh[:,t,:]+dnext_h, dnext_c, cache[t])
#     431         dWx += dWx_add
#     432         dWh += dWh_add
#
# /home/heerad/dev/cs231n/assignment3/cs231n/rnn_layers.py in lstm_step_backward(dnext_h, dnext_c, cache)
#     333     dA[:,(3*H):] = (1. - np.tanh(A[:,(3*H):])**2) * dg
#     334
# --> 335     dx = np.dot(dA,Wx.T)
#     336     dprev_h = np.dot(dA,Wh.T)
#     337     dprev_c = f * dnext_c_total
#
# KeyboardInterrupt:

# %%
evaluate_model(lstm_model)

# Plot the training losses
plt.plot(lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# Average BLEU score for train: 0.157388
# Average BLEU score for val: 0.159557

# %%
for split in ['train', 'val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])

    sample_captions = lstm_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])

    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\nGT:%s' % (split, sample_caption, gt_caption))
        plt.axis('off')
        plt.show()
